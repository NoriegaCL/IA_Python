# %% [markdown]
# <a href="https://colab.research.google.com/github/NoriegaCL/IA_Python/blob/main/ValorImovel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a63865c4-a382-4c33-9973-df752dc9c524" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a63865c4-a382-4c33-9973-df752dc9c524">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# lendo o arquivo USA_Housing.csv
df = pd.read_csv('USA_Housing.csv')

# %%
# Exibindo as colunas
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %% [markdown]
# ●	Dicionário de Dados
# O dataframe contém as seguintes colunas:
# •'Avg. Area Income': A renda média dos residentes da cidade onde a casa está localizada.
# •'Avg. Area House Age': Idade média das casas na mesma cidade.
# •'Avg. Area Number of Rooms': Número Médio de Cômodos para Casas na mesma cidade.
# •'Avg. Area Number of Bedrooms': Número Médio de Quartos para Casas na mesma cidade.
# •'Area Population': a população da cidade onde está localizada as Casas.
# •'Price': preço em que a casa foi vendida.
# •'Address': Endereço da casa.

# %%
# excluir a coluna endereço
df.drop('Address',axis=1,inplace=True)

# %%
# Normalizando o dataframe
normalized_df=(df-df.min())/(df.max()-df.min())

# %%
X = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Avg. Area Number of Bedrooms', 'Area Population']]
y = df['Price']
X.head()
y.head()
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
from sklearn.linear_model import LinearRegression

# %%
# Aqui criamos o modelo preditor
modelopreditor = LinearRegression()

# %%
# Aqui ocorre o aprendizado
modelopreditor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Imprimindo os coeficientes com os nomes das colunas
coeff = pd.DataFrame(modelopreditor.coef_,X.columns,columns=['Coeficiente'])
coeff
# Out:
#                                 Coeficiente
# Avg. Area Income                  21.525435
# Avg. Area House Age           166415.114396
# Avg. Area Number of Rooms     119802.717039
# Avg. Area Number of Bedrooms    1783.166098
# Area Population                   15.387540

# %%
# fazendo predições com os dados de teste
predictions = modelopreditor.predict(X_test)

# %%
# imprimindo as primeiras variáveis preditoras
X_test.head()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3431      50570.864807             5.828143                   4.851423
# 2042      65314.720112             6.918945                   6.245656
# 79        64419.252638             6.954422                   8.516160
# 4663      60390.502855             5.195406                   8.368913
# 3640      73068.518101             7.271422                   5.685408
#
#       Avg. Area Number of Bedrooms  Area Population
# 3431                          4.36     40580.092291
# 2042                          2.42     36565.029831
# 79                            6.16     39318.170755
# 4663                          6.27     37921.720586
# 3640                          3.14     42929.876157

# %%
# Predições realizadas
predictions
# Out:
# array([ 631305.05842544, 1231990.56161569, 1539664.80551485, ...,
#        1251986.62330197, 1036432.95159307, 1553580.80137907])

# %%
# Valores reais para acertar
y_test.head()
# Out:
# 3431    6.129387e+05
# 2042    1.347083e+06
# 79      1.492011e+06
# 4663    1.223915e+06
# 3640    1.368692e+06
# Name: Price, dtype: float64

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print('r2',metrics.r2_score(y_test, predictions) )
# Out:
# MAE: 80728.93384538879
# MSE: 10077066685.864893
# RMSE: 100384.59386711137
# r2 0.9186390166173336
